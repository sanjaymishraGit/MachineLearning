# %%
n_Epochs = int(input("Enter number of Epochs for RNN Training"))
# Out:
# Enter number of Epochs for RNN Training100

# %%
import pandas as pd
original_ign = pd.read_csv("ign.csv")
original_ign.head(10)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
# 5           5         Good                          Total War Battles: Shogun
# 6           6        Awful                                Double Dragon: Neon
# 7           7      Amazing                                       Guild Wars 2
# 8           8        Awful                                Double Dragon: Neon
# 9           9         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# 5         /games/total-war-battles-shogun/mac-142565         Macintosh    7.0
# 6          /games/double-dragon-neon/xbox-360-131320          Xbox 360    3.0
# 7                      /games/guild-wars-2/pc-896298                PC    9.0
# 8               /games/double-dragon-neon/ps3-131321     PlayStation 3    3.0
# 9          /games/total-war-battles-shogun/pc-142564                PC    7.0
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11
# 5    Strategy              N          2012              9           11
# 6    Fighting              N          2012              9           11
# 7         RPG              Y          2012              9           11
# 8    Fighting              N          2012              9           11
# 9    Strategy              N          2012              9           11

# %%
#Shape of the data set
original_ign.shape
# Out:
# (18625, 11)

# %%
#Count diffrent emotios and their values in the data set
original_ign.score_phrase.value_counts()
# Out:
# Great          4773
# Good           4741
# Okay           2945
# Mediocre       1959
# Amazing        1804
# Bad            1269
# Awful           664
# Painful         340
# Unbearable       72
# Masterpiece      55
# Disaster          3
# Name: score_phrase, dtype: int64

# %%
#Data Preprocessing
#Step1: Convert all scores to binary sentimens ( Possitive and Negative) by adding new column: we need to support binary sentiment classification also
#Step2: Remoove Disaster as we dont have enough data for Disaster 
#Step3:Check if there are any columns whose value is null, fill it with Empty string
#Step4: Create new data frame with 'sentiment', 'score_phrase', 'title', 'platform', 'genre', 'editors_choice'
#Step5:Create new column called  'is_editors_choice' in text only for where editor choice is true
#Step6: Create a new column called text which contains value from 'title'+'platform'+'genre''is_editors_choice'

#Step1: new Column 'sentiment
bad_phrases = ['Bad','Awful','Painful','Unbearable','Disaster']
original_ign['sentiment'] = original_ign.score_phrase.isin(bad_phrases).map({True: 'Negative', False:'Possitive'})

#Step2: Remove "Disaster"
original_ign = original_ign[original_ign['score_phrase'] != 'Disaster']
original_ign.head(10)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
# 5           5         Good                          Total War Battles: Shogun
# 6           6        Awful                                Double Dragon: Neon
# 7           7      Amazing                                       Guild Wars 2
# 8           8        Awful                                Double Dragon: Neon
# 9           9         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# 5         /games/total-war-battles-shogun/mac-142565         Macintosh    7.0
# 6          /games/double-dragon-neon/xbox-360-131320          Xbox 360    3.0
# 7                      /games/guild-wars-2/pc-896298                PC    9.0
# 8               /games/double-dragon-neon/ps3-131321     PlayStation 3    3.0
# 9          /games/total-war-battles-shogun/pc-142564                PC    7.0
#
#         genre editors_choice  release_year  release_month  release_day  \
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11
# 5    Strategy              N          2012              9           11
# 6    Fighting              N          2012              9           11
# 7         RPG              Y          2012              9           11
# 8    Fighting              N          2012              9           11
# 9    Strategy              N          2012              9           11
#
#    sentiment
# 0  Possitive
# 1  Possitive
# 2  Possitive
# 3  Possitive
# 4  Possitive
# 5  Possitive
# 6   Negative
# 7  Possitive
# 8   Negative
# 9  Possitive

# %%
original_ign.sentiment.value_counts(normalize=True)
# Out:
# Possitive    0.874074
# Negative     0.125926
# Name: sentiment, dtype: float64

# %%
#Step: Find all null values and fill with empty value
original_ign.isnull().sum()
# Out:
# Unnamed: 0         0
# score_phrase       0
# title              0
# url                0
# platform           0
# score              0
# genre             36
# editors_choice     0
# release_year       0
# release_month      0
# release_day        0
# sentiment          0
# dtype: int64

# %%
original_ign.fillna(value = '' , inplace =True)

# %%
# Out:
# Unnamed: 0        0
# score_phrase      0
# title             0
# url               0
# platform          0
# score             0
# genre             0
# editors_choice    0
# release_year      0
# release_month     0
# release_day       0
# sentiment         0
# dtype: int64

# %%
#Step4: Create new data frame with 'sentiment', 'score_phrase', 'title', 'platform', 'genre', 'editors_choice'
ign = original_ign[['sentiment','score_phrase','title','platform','genre','editors_choice']].copy()
ign.head(10)
# Out:
#    sentiment score_phrase                                              title  \
# 0  Possitive      Amazing                            LittleBigPlanet PS Vita
# 1  Possitive      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2  Possitive        Great                               Splice: Tree of Life
# 3  Possitive        Great                                             NHL 13
# 4  Possitive        Great                                             NHL 13
# 5  Possitive         Good                          Total War Battles: Shogun
# 6   Negative        Awful                                Double Dragon: Neon
# 7  Possitive      Amazing                                       Guild Wars 2
# 8   Negative        Awful                                Double Dragon: Neon
# 9  Possitive         Good                          Total War Battles: Shogun
#
#            platform       genre editors_choice
# 0  PlayStation Vita  Platformer              Y
# 1  PlayStation Vita  Platformer              Y
# 2              iPad      Puzzle              N
# 3          Xbox 360      Sports              N
# 4     PlayStation 3      Sports              N
# 5         Macintosh    Strategy              N
# 6          Xbox 360    Fighting              N
# 7                PC         RPG              Y
# 8     PlayStation 3    Fighting              N
# 9                PC    Strategy              N

# %%
#Step5:Create new column called  'is_editors_choice' in text only for where editors_choice is true
ign['is_editors_choice'] = ign['editors_choice'].map({'Y': 'editors_choice', 'N': ''})
ign.head(10)
# Out:
#    sentiment score_phrase                                              title  \
# 0  Possitive      Amazing                            LittleBigPlanet PS Vita
# 1  Possitive      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2  Possitive        Great                               Splice: Tree of Life
# 3  Possitive        Great                                             NHL 13
# 4  Possitive        Great                                             NHL 13
# 5  Possitive         Good                          Total War Battles: Shogun
# 6   Negative        Awful                                Double Dragon: Neon
# 7  Possitive      Amazing                                       Guild Wars 2
# 8   Negative        Awful                                Double Dragon: Neon
# 9  Possitive         Good                          Total War Battles: Shogun
#
#            platform       genre editors_choice is_editors_choice
# 0  PlayStation Vita  Platformer              Y    editors_choice
# 1  PlayStation Vita  Platformer              Y    editors_choice
# 2              iPad      Puzzle              N
# 3          Xbox 360      Sports              N
# 4     PlayStation 3      Sports              N
# 5         Macintosh    Strategy              N
# 6          Xbox 360    Fighting              N
# 7                PC         RPG              Y    editors_choice
# 8     PlayStation 3    Fighting              N
# 9                PC    Strategy              N

# %%
#Step6: Create a new column called text which contains value from 'title'+'platform'+'genre''is_editors_choice'
ign['text'] = ign['title'].str.cat(ign['platform'], sep=' ').str.cat(ign['genre'], sep=' ').str.cat(ign['is_editors_choice'], sep=' ')
ign.head(10)
# Out:
#    sentiment score_phrase                                              title  \
# 0  Possitive      Amazing                            LittleBigPlanet PS Vita
# 1  Possitive      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2  Possitive        Great                               Splice: Tree of Life
# 3  Possitive        Great                                             NHL 13
# 4  Possitive        Great                                             NHL 13
# 5  Possitive         Good                          Total War Battles: Shogun
# 6   Negative        Awful                                Double Dragon: Neon
# 7  Possitive      Amazing                                       Guild Wars 2
# 8   Negative        Awful                                Double Dragon: Neon
# 9  Possitive         Good                          Total War Battles: Shogun
#
#            platform       genre editors_choice is_editors_choice  \
# 0  PlayStation Vita  Platformer              Y    editors_choice
# 1  PlayStation Vita  Platformer              Y    editors_choice
# 2              iPad      Puzzle              N
# 3          Xbox 360      Sports              N
# 4     PlayStation 3      Sports              N
# 5         Macintosh    Strategy              N
# 6          Xbox 360    Fighting              N
# 7                PC         RPG              Y    editors_choice
# 8     PlayStation 3    Fighting              N
# 9                PC    Strategy              N
#
#                                                 text
# 0  LittleBigPlanet PS Vita PlayStation Vita Platf...
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                  Splice: Tree of Life iPad Puzzle
# 3                            NHL 13 Xbox 360 Sports
# 4                       NHL 13 PlayStation 3 Sports
# 5      Total War Battles: Shogun Macintosh Strategy
# 6             Double Dragon: Neon Xbox 360 Fighting
# 7                 Guild Wars 2 PC RPG editors_choice
# 8        Double Dragon: Neon PlayStation 3 Fighting
# 9             Total War Battles: Shogun PC Strategy

# %%
'''
Here, I'll treat this as a multiclass problem where I attempt to predict the labels (i.e. the score_phrases) 
Examples of score_phrases:
Great 
Good 
Okay 
Mediocre 
Amazing 
Bad 
Awful 
Painful 
Unbearable 
Masterpiece 
'''
# Out:
# "\nHere, I'll treat this as a multiclass problem where I attempt to predict the labels (i.e. the score_phrases)¶ \nExamples of score_phrases:\nGreat \nGood \nOkay \nMediocre \nAmazing \nBad \nAwful \nPainful \nUnbearable \nMasterpiece \n"

# %%
X= ign.text
y= ign.score_phrase

# %%
X.head(10)
# Out:
# 0    LittleBigPlanet PS Vita PlayStation Vita Platf...
# 1    LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                    Splice: Tree of Life iPad Puzzle
# 3                              NHL 13 Xbox 360 Sports
# 4                         NHL 13 PlayStation 3 Sports
# 5        Total War Battles: Shogun Macintosh Strategy
# 6               Double Dragon: Neon Xbox 360 Fighting
# 7                   Guild Wars 2 PC RPG editors_choice
# 8          Double Dragon: Neon PlayStation 3 Fighting
# 9               Total War Battles: Shogun PC Strategy
# Name: text, dtype: object

# %%
y.head(10)
# Out:
# 0    Amazing
# 1    Amazing
# 2      Great
# 3      Great
# 4      Great
# 5       Good
# 6      Awful
# 7    Amazing
# 8      Awful
# 9       Good
# Name: score_phrase, dtype: object

# %%
#RNN Classifier using TF Learn
import tflern
from tflearn.data_utils import to_categorical, pad_sequences
from tflearn.datasets import imdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-646e04f03e41> in <module>()
#       1 #RNN Classifier using TF Learn
# ----> 2 import tflern
#       3 from tflearn.data_utils import to_categorical, pad_sequences
#       4 from tflearn.datasets import imdb
#
# ModuleNotFoundError: No module named 'tflern'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
#Create a vocab , so that we can X_word_ids from X
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(ngram_range=(1,1), token_pattern=r'\b\w{1,}\b')
vect.fit(X_train)
vocab = vect.vocabulary_
vocab
# Out:
# {'castlevania': 1267,
#  'harmony': 3134,
#  'of': 4717,
#  'despair': 1911,
#  'playstation': 5074,
#  '3': 149,
#  'action': 251,
#  'adventure': 269,
#  'kim': 3730,
#  'possible': 5126,
#  '2': 77,
#  'drakken': 2104,
#  's': 5693,
#  'demise': 1888,
#  'game': 2799,
#  'boy': 1025,
#  'advance': 266,
#  'platformer': 5062,
#  'editors_choice': 2227,
#  'madden': 4037,
#  'nfl': 4585,
#  '09': 13,
#  'sports': 6257,
#  'wwe': 7447,
#  '2k16': 136,
#  'xbox': 7458,
#  'one': 4751,
#  'wrestling': 7439,
#  'the': 6674,
#  'last': 3843,
#  'ninja': 4617,
#  'commodore': 1533,
#  '64': 182,
#  '128': 31,
#  'l': 3807,
#  'a': 215,
#  'i': 3361,
#  'steel': 6359,
#  'lancer': 3825,
#  'arena': 509,
#  'international': 3477,
#  'samurai': 5722,
#  'shodown': 5930,
#  'v': 7101,
#  'fighting': 2556,
#  'kurt': 3801,
#  'warner': 7265,
#  'football': 2656,
#  'unleashed': 7074,
#  'worldshift': 7427,
#  'pc': 4931,
#  'strategy': 6401,
#  'worms': 7430,
#  'armageddon': 522,
#  '360': 155,
#  'eye': 2437,
#  'rana': 5348,
#  'wireless': 7380,
#  'rpg': 5654,
#  'sonic': 6159,
#  'riders': 5534,
#  'racing': 5312,
#  'tribes': 6906,
#  'ascend': 549,
#  'tom': 6780,
#  'clancy': 1425,
#  'hawx': 3151,
#  'wii': 7345,
#  'flight': 2620,
#  'mega': 4204,
#  'man': 4089,
#  'legends': 3880,
#  'lufia': 4006,
#  'curse': 1728,
#  'sinistrals': 6013,
#  'nintendo': 4621,
#  'ds': 2145,
#  'mr': 4437,
#  'driller': 2121,
#  'dreamcast': 2110,
#  'puzzle': 5261,
#  'teenage': 6624,
#  'mutant': 4471,
#  'turtles': 6978,
#  '2003': 82,
#  'star': 6309,
#  'trek': 6896,
#  'tactical': 6559,
#  'assault': 563,
#  'portable': 5119,
#  'simulation': 6000,
#  'hummer': 3328,
#  'badlands': 664,
#  'political': 5098,
#  'machine': 4029,
#  'battletanx': 757,
#  'lego': 3883,
#  'wars': 7274,
#  'ii': 3382,
#  'original': 4795,
#  'trilogy': 6916,
#  'gamecube': 2802,
#  'incoming': 3419,
#  'pop': 5109,
#  'em': 2277,
#  'drop': 2133,
#  'samegame': 5719,
#  'midway': 4267,
#  'arcade': 494,
#  'treasures': 6891,
#  'compilation': 1537,
#  'darksiders': 1801,
#  'twisted': 6990,
#  'metal': 4238,
#  'kartia': 3678,
#  'medal': 4198,
#  'honor': 3275,
#  'european': 2366,
#  'shooter': 5936,
#  'goat': 2916,
#  'simulator': 6001,
#  'n': 4494,
#  'deus': 1930,
#  'ex': 2391,
#  'human': 3325,
#  'revolution': 5510,
#  'sims': 5999,
#  'bustin': 1166,
#  'out': 4812,
#  'ssx': 6291,
#  'bounds': 1012,
#  'gage': 2779,
#  'dragon': 2091,
#  'ball': 676,
#  'z': 7536,
#  'buu': 1174,
#  'fury': 2762,
#  'deer': 1863,
#  'hunter': 3333,
#  'tournament': 6832,
#  'hunting': 3336,
#  'sega': 5824,
#  'superstars': 6488,
#  'tennis': 6642,
#  'naruto': 4521,
#  'council': 1617,
#  'carmageddon': 1236,
#  'tdr': 6606,
#  '2000': 79,
#  'spec': 6204,
#  'ops': 4772,
#  'line': 3928,
#  'rez': 5514,
#  'music': 4468,
#  'bomberman': 971,
#  'blast': 889,
#  'golden': 2937,
#  'axe': 629,
#  'iphone': 3500,
#  'spyro': 6278,
#  'ripto': 5555,
#  'quest': 5288,
#  'unreal': 7080,
#  'championship': 1320,
#  'teleglitch': 6626,
#  'die': 1953,
#  'more': 4390,
#  'edition': 2225,
#  'banjo': 697,
#  'kazooie': 3692,
#  'nuts': 4682,
#  'bolts': 966,
#  'spikeout': 6232,
#  'battle': 733,
#  'street': 6406,
#  'amazing': 395,
#  'spider': 6228,
#  'ghost': 2873,
#  'recon': 5413,
#  'future': 2768,
#  'soldier': 6146,
#  'gumboy': 3047,
#  'tiger': 6731,
#  'woods': 7411,
#  'pga': 4970,
#  'tour': 6829,
#  '10': 15,
#  'batman': 729,
#  'arkham': 517,
#  'origins': 4796,
#  'blackgate': 874,
#  'deluxe': 1883,
#  'soul': 6170,
#  'blade': 884,
#  'coded': 1482,
#  'arms': 531,
#  'contagion': 1569,
#  'desperate': 1914,
#  'housewives': 3312,
#  'life': 3909,
#  'is': 3511,
#  'strange': 6397,
#  'episode': 2327,
#  'chaos': 1328,
#  'theory': 6682,
#  '4': 160,
#  'donkey': 2057,
#  'kong': 3780,
#  'country': 1622,
#  'returns': 5496,
#  '3d': 156,
#  '3ds': 157,
#  'bad': 659,
#  'boys': 1027,
#  'miami': 4249,
#  'takedown': 6569,
#  'asura': 577,
#  'wrath': 7433,
#  'bode': 955,
#  'miller': 4281,
#  'alpine': 379,
#  'skiing': 6038,
#  'vengeance': 7143,
#  'color': 1506,
#  'hitman': 3237,
#  'summer': 6455,
#  'athletics': 587,
#  'ultimate': 7015,
#  'challenge': 1311,
#  'xenosaga': 7466,
#  'iii': 3383,
#  'also': 380,
#  'sprach': 6264,
#  'zarathustra': 7542,
#  'emperor': 2283,
#  'new': 4577,
#  'groove': 3014,
#  'dead': 1833,
#  'rising': 5559,
#  'triple': 6921,
#  'pack': 4851,
#  'tales': 6574,
#  'monkey': 4368,
#  'island': 3515,
#  'chapter': 1331,
#  '1': 14,
#  'launch': 3846,
#  'screaming': 5793,
#  'narwhal': 4522,
#  'legend': 3877,
#  'zelda': 7552,
#  'majora': 4070,
#  'mask': 4139,
#  'rage': 5322,
#  'armored': 528,
#  'core': 1597,
#  'formula': 2669,
#  'front': 2729,
#  'extreme': 2435,
#  'pac': 4848,
#  'world': 7425,
#  '20th': 108,
#  'anniversary': 453,
#  'wild': 7349,
#  'train': 6861,
#  'pokemon': 5088,
#  'cyberball': 1739,
#  '2072': 103,
#  'horizon': 3289,
#  'gundam': 3050,
#  'side': 5965,
#  'story': 6395,
#  '0079': 3,
#  'mart': 4130,
#  'racer': 5308,
#  'digimon': 1961,
#  'hero': 3205,
#  'match': 4149,
#  'up': 7089,
#  'dsi': 2146,
#  'backyard': 657,
#  '2006': 85,
#  'warlords': 7264,
#  'nba': 4535,
#  '08': 12,
#  'floe': 2632,
#  'little': 3941,
#  'bear': 772,
#  'needs': 4549,
#  'your': 7528,
#  'help': 3193,
#  'gladiator': 2896,
#  'sword': 6533,
#  'pool': 5107,
#  'party': 4907,
#  'micro': 4257,
#  'machines': 4030,
#  '2002': 81,
#  'family': 2481,
#  'feud': 2539,
#  'trivia': 6925,
#  'quantum': 5282,
#  'conundrum': 1585,
#  'penny': 4948,
#  'on': 4749,
#  'rain': 5336,
#  'slick': 6071,
#  'precipice': 5153,
#  'darkness': 1800,
#  'war': 7244,
#  'scrabble': 5783,
#  '2007': 86,
#  'ricochet': 5528,
#  'hd': 3157,
#  'babel': 646,
#  'go': 2914,
#  'beckham': 789,
#  'soccer': 6135,
#  'cave': 1285,
#  'far': 2488,
#  'cry': 1700,
#  'instincts': 3463,
#  'elite': 2272,
#  'excitebike': 2398,
#  'classic': 1432,
#  'nes': 4566,
#  'series': 5846,
#  'typing': 7001,
#  'educational': 2232,
#  'intellivision': 3470,
#  'astrosmash': 576,
#  'wcw': 7298,
#  'mayhem': 4171,
#  'talons': 6576,
#  'lynx': 4019,
#  'path': 4916,
#  'york': 7523,
#  'rollercoaster': 5619,
#  'rush': 5684,
#  'p': 4847,
#  '03': 7,
#  'dogz': 2034,
#  'virtual': 7193,
#  'pet': 4965,
#  'necrovision': 4545,
#  'destruction': 1924,
#  'derby': 1900,
#  'arenas': 510,
#  'fallout': 2475,
#  'operation': 4767,
#  'anchorage': 424,
#  'chop': 1387,
#  'til': 6736,
#  'you': 7526,
#  'incredible': 3420,
#  'hulk': 3324,
#  'frontline': 2733,
#  'command': 1529,
#  'starship': 6330,
#  'troopers': 6934,
#  'terran': 6651,
#  'ascendancy': 550,
#  'fighters': 2555,
#  'uncaged': 7025,
#  'phantasy': 4975,
#  'space': 6184,
#  'bust': 1163,
#  'move': 4428,
#  'leadfoot': 3859,
#  'stadium': 6297,
#  'off': 4718,
#  'road': 5573,
#  'lost': 3990,
#  'planet': 5050,
#  'condition': 1547,
#  'crazy': 1652,
#  'penguin': 4945,
#  'catapult': 1273,
#  'spyhunter': 6277,
#  'coast': 1472,
#  'walking': 7234,
#  'season': 5811,
#  'two': 6992,
#  'amid': 403,
#  'ruins': 5667,
#  'drome': 2130,
#  'racers': 5309,
#  'socom': 6139,
#  'u': 7006,
#  'navy': 4534,
#  'seals': 5806,
#  'fireteam': 2581,
#  'bravo': 1042,
#  'dance': 1781,
#  'central': 1301,
#  'cabela': 1181,
#  'trophy': 6937,
#  'bucks': 1112,
#  'motocross': 4413,
#  'maniacs': 4099,
#  'paperboy': 4883,
#  'deal': 1839,
#  'or': 4773,
#  'no': 4632,
#  'final': 2564,
#  'fantasy': 2486,
#  'viii': 7177,
#  'resident': 5474,
#  'evil': 2384,
#  'code': 1481,
#  'veronica': 7151,
#  'shadow': 5872,
#  'harvest': 3138,
#  'phantom': 4976,
#  'back': 651,
#  'to': 6764,
#  'citizen': 1416,
#  'brown': 1093,
#  'alien': 359,
#  'isolation': 3519,
#  'sahara': 5704,
#  'slug': 6083,
#  'x': 7451,
#  'v4': 7105,
#  'dave': 1816,
#  'mirra': 4320,
#  'freestyle': 2710,
#  'bmx': 941,
#  'warriors': 7273,
#  'orochi': 4799,
#  'blades': 885,
#  'blood': 925,
#  'iron': 3507,
#  'aces': 242,
#  'among': 410,
#  'sleep': 6067,
#  'guilty': 3043,
#  'gear': 2836,
#  'xrd': 7486,
#  'sign': 5973,
#  'amf': 402,
#  'xtreme': 7488,
#  'bowling': 1017,
#  'elder': 2250,
#  'scrolls': 5799,
#  'bloodmoon': 929,
#  'chocobo': 1382,
#  'panic': 4874,
#  'ipad': 3499,
#  'motogp': 4414,
#  'diablo': 1942,
#  'folklore': 2651,
#  'mana': 4090,
#  'arcania': 499,
#  'gothic': 2956,
#  'iv': 3528,
#  '2k13': 133,
#  'everquest': 2376,
#  'odyssey': 4716,
#  'chronicles': 1399,
#  'riddick': 5529,
#  'dark': 1795,
#  'athena': 583,
#  'virtua': 7192,
#  'fighter': 2554,
#  '5': 168,
#  'online': 4755,
#  'video': 7168,
#  'grim': 3002,
#  'adventures': 271,
#  'billy': 851,
#  'mandy': 4094,
#  'ncaa': 4537,
#  '12': 30,
#  'pixeljunk': 5036,
#  'hack': 3082,
#  'g': 2774,
#  'vol': 7206,
#  'redemption': 5421,
#  'buzz': 1175,
#  'quiz': 5296,
#  '2004': 83,
#  'piece': 4999,
#  'burning': 1155,
#  'dungeons': 2170,
#  'dragons': 2096,
#  'stormreach': 6393,
#  'rainbow': 5337,
#  'six': 6022,
#  'siege': 5969,
#  'rock': 5599,
#  'band': 686,
#  'special': 6205,
#  'battleship': 751,
#  'surface': 6492,
#  'thunder': 6722,
#  'jaws': 3566,
#  'empire': 2284,
#  'earth': 2197,
#  'godfather': 2926,
#  'limited': 3926,
#  'long': 3973,
#  'ahead': 311,
#  'smackdown': 6088,
#  'vs': 7219,
#  'raw': 5374,
#  '2011': 90,
#  'halo': 3095,
#  'collector': 1497,
#  'praetorians': 5150,
#  'bioshock': 861,
#  'irritating': 3510,
#  'stick': 6372,
#  'ambitions': 398,
#  'looney': 3978,
#  'tunes': 6965,
#  'alert': 350,
#  'history': 3233,
#  'channel': 1326,
#  'for': 2657,
#  'pacific': 4850,
#  'peter': 4966,
#  'pan': 4868,
#  'in': 3411,
#  'disney': 1994,
#  'return': 5495,
#  'never': 4572,
#  'land': 3826,
#  'ys': 7531,
#  'seven': 5858,
#  'showdown': 5953,
#  'hand': 3112,
#  'fate': 2504,
#  'card': 1230,
#  'desperados': 1913,
#  'wanted': 7242,
#  'alive': 361,
#  'fifa': 2551,
#  'cup': 1725,
#  'how': 3314,
#  'survive': 6502,
#  'rocky': 5607,
#  'combat': 1516,
#  'mission': 4331,
#  'beyond': 832,
#  'overlord': 4836,
#  'mlb': 4341,
#  'show': 5951,
#  'clu': 1461,
#  'famicom': 2480,
#  'mini': 4301,
#  '96': 207,
#  'prince': 5179,
#  'persia': 4960,
#  'sam': 5717,
#  'max': 4163,
#  'abe': 224,
#  'lincoln': 3927,
#  'must': 4470,
#  'harry': 3136,
#  'potter': 5131,
#  'years': 7510,
#  'age': 300,
#  'leliana': 3886,
#  'song': 6158,
#  'gravity': 2982,
#  'crash': 1642,
#  'inside': 3461,
#  'wasteland': 7284,
#  'angel': 433,
#  'rayman': 5378,
#  'vita': 7199,
#  'paper': 4882,
#  'mario': 4124,
#  'thousand': 6705,
#  'year': 7509,
#  'door': 2063,
#  'and': 427,
#  'half': 3090,
#  'jamestown': 3555,
#  'colony': 1505,
#  'mtv': 4440,
#  't': 6552,
#  'j': 3535,
#  'lavin': 3848,
#  'who': 7340,
#  'that': 6673,
#  'flying': 2646,
#  'bio': 857,
#  'f': 2443,
#  'r': 5298,
#  'e': 2188,
#  'k': 3647,
#  'gripshift': 3010,
#  'fox': 2684,
#  'college': 1499,
#  'hoops': 3281,
#  '99': 211,
#  'all': 362,
#  'trivial': 6926,
#  'pursuit': 5255,
#  'assassin': 561,
#  'creed': 1659,
#  'china': 1374,
#  'hurrydate': 3340,
#  'speeddaters': 6213,
#  'zero': 7563,
#  'espn': 2346,
#  '2night': 146,
#  'revelations': 5500,
#  'tsunami': 6956,
#  '2265': 119,
#  'north': 4650,
#  'south': 6180,
#  'great': 2985,
#  'american': 400,
#  'civil': 1420,
#  'live': 3944,
#  'furi': 2757,
#  '2010': 89,
#  'call': 1194,
#  'duty': 2178,
#  'gangs': 2812,
#  'london': 3970,
#  'simpsons': 5997,
#  'hit': 3234,
#  'run': 5675,
#  'hi': 3215,
#  'hamtaro': 3109,
#  'ham': 3096,
#  'grand': 2970,
#  'theft': 6678,
#  'auto': 611,
#  'episodes': 2328,
#  'from': 2728,
#  'liberty': 3903,
#  'city': 1418,
#  'iggy': 3376,
#  'reckin': 5409,
#  'balls': 683,
#  'bubble': 1104,
#  'bobble': 951,
#  'old': 4736,
#  'darklords': 1799,
#  'guitar': 3045,
#  'borderlands': 999,
#  'tiny': 6751,
#  'tina': 6748,
#  'keep': 3695,
#  'crime': 1666,
#  'cities': 1415,
#  'stretch': 6411,
#  'grooves': 3016,
#  'knockout': 3762,
#  'kings': 3739,
#  'damrey': 1779,
#  'nhl': 4587,
#  'faceoff': 2452,
#  'plane': 5046,
#  'fortune': 2675,
#  'payback': 4925,
#  'test': 6660,
#  'drive': 2123,
#  'rise': 5556,
#  'sin': 6002,
#  'tzu': 7005,
#  'treasure': 6890,
#  'strike': 6413,
#  'zapper': 7541,
#  'wicked': 7342,
#  'cricket': 1665,
#  'tetris': 6663,
#  'movie': 4430,
#  'videogame': 7169,
#  'paintbrawl': 4860,
#  'braid': 1032,
#  'supernova': 6483,
#  'spacewar': 6189,
#  'rebel': 5401,
#  'raiders': 5329,
#  'nighthawk': 4603,
#  'super': 6471,
#  'turbo': 6968,
#  'revival': 5508,
#  'compass': 1535,
#  'kung': 3798,
#  'fu': 2743,
#  'panda': 4869,
#  'zone': 7579,
#  'warrior': 7272,
#  'extraction': 2433,
#  'joe': 3602,
#  'cobra': 1476,
#  'tobe': 6769,
#  'vertical': 7155,
#  'sx': 6537,
#  'superstar': 6487,
#  'potpourrii': 5130,
#  'dinosaur': 1973,
#  'ecco': 2208,
#  'dolphin': 2042,
#  'defender': 1870,
#  'collection': 1496,
#  'rules': 5670,
#  'get': 2868,
#  'phat': 4981,
#  'whispering': 7334,
#  'willows': 7356,
#  'dexter': 1939,
#  'jam': 3550,
#  'scratches': 5790,
#  'total': 6819,
#  'immersion': 3398,
#  'shaun': 5901,
#  'white': 7336,
#  'snowboarding': 6131,
#  'target': 6594,
#  'urbz': 7094,
#  'chuck': 1405,
#  'ghostbusters': 2874,
#  'legacy': 3874,
#  'naughty': 4531,
#  'paradise': 4890,
#  'monopoly': 4373,
#  'board': 943,
#  'banzai': 700,
#  'rabbit': 5304,
#  'crystal': 1704,
#  'echoes': 2212,
#  'time': 6741,
#  'shantae': 5888,
#  'pirate': 5024,
#  'need': 4548,
#  'speed': 6211,
#  'most': 4403,
#  '2005': 84,
#  'sheep': 5902,
#  'retribution': 5490,
#  'syberia': 6538,
#  'grudge': 3025,
#  'capcom': 1218,
#  'snk': 6121,
#  'eo': 2321,
#  'lone': 3971,
#  'survivor': 6504,
#  'director': 1978,
#  'cut': 1732,
#  'blowout': 934,
#  'tmnt': 6761,
#  'power': 5134,
#  'four': 2682,
#  'magical': 4050,
#  'roses': 5643,
#  'aion': 318,
#  'citizens': 1417,
#  'castrol': 1268,
#  'honda': 3271,
#  'superbike': 6472,
#  'champions': 1319,
#  'torgue': 6807,
#  'campaign': 1203,
#  'carnage': 1239,
#  'botanicula': 1005,
#  'skateboarding': 6029,
#  'featuring': 2519,
#  'andy': 432,
#  'macdonald': 4025,
#  'ice': 3367,
#  'dawn': 1820,
#  'dinosaurs': 1974,
#  'madagascar': 4035,
#  'kartz': 3680,
#  'brink': 1079,
#  'high': 3218,
#  'school': 5769,
#  'musical': 4469,
#  'senior': 5832,
#  'toca': 6770,
#  'warhammer': 7257,
#  'arma': 519,
#  'operations': 4769,
#  'race': 5307,
#  'lemony': 3889,
#  'snicket': 6119,
#  'unfortunate': 7054,
#  'events': 2371,
#  'open': 4766,
#  'business': 1162,
#  'singstar': 6009,
#  'hasbro': 3140,
#  'night': 4598,
#  'annihilation': 452,
#  'kingdoms': 3737,
#  'crysis': 1703,
#  'warhead': 7259,
#  'avatar': 618,
#  'airbender': 321,
#  'second': 5813,
#  'sight': 5970,
#  'aliens': 360,
#  'colonial': 1502,
#  'marines': 4123,
#  'diaspora': 1948,
#  'shattered': 5900,
#  'armistice': 526,
#  'populous': 5116,
#  'ultra': 7018,
#  'minigolf': 4304,
#  'garfield': 2822,
#  'pooky': 5106,
#  '32x': 153,
#  'nightclub': 4600,
#  'anne': 450,
#  'mccaffrey': 4175,
#  'freedom': 2704,
#  'first': 2585,
#  'resistance': 5475,
#  'driver': 2126,
#  'muscle': 4464,
#  'car': 1227,
#  'twilight': 6983,
#  'princess': 5180,
#  'next': 4582,
#  'zer0': 7561,
#  'sum': 6453,
#  'top': 6800,
#  'chef': 1352,
#  'noby': 4636,
#  'void': 7205,
#  'major': 4069,
#  'minor': 4313,
#  'majestic': 4066,
#  'march': 4118,
#  'mirror': 4321,
#  'edge': 2223,
#  'ty': 6995,
#  'tasmanian': 6598,
#  'bush': 1160,
#  'rescue': 5469,
#  'ninjas': 4619,
#  'reservoir': 5471,
#  'dogs': 2033,
#  'hercules': 3200,
#  'tortuga': 6815,
#  'marvel': 4134,
#  'heroes': 3207,
#  'kill': 3726,
#  'switch': 6528,
#  'limbo': 3924,
#  'sun': 6460,
#  'divided': 2007,
#  'ground': 3021,
#  'middle': 4263,
#  'east': 2201,
#  'conflict': 1551,
#  '1948': 56,
#  '1973': 59,
#  'nppl': 4672,
#  'paintball': 4859,
#  '2009': 88,
#  'pinball': 5014,
#  'bigs': 843,
#  'flock': 2631,
#  're': 5386,
#  'loaded': 3950,
#  'hardcore': 3124,
#  'sequel': 5841,
#  'splinter': 6249,
#  'cell': 1294,
#  'pandora': 4872,
#  'tomorrow': 6786,
#  'zorro': 7588,
#  'asteroids': 571,
#  'hyper': 3352,
#  'sleeping': 6068,
#  'definitive': 1875,
#  'swat': 6518,
#  'force': 2659,
#  'happy': 3120,
#  'feet': 2525,
#  'milo': 4285,
#  'astro': 574,
#  'lanes': 3832,
#  'wario': 7260,
#  'forza': 2676,
#  'presents': 5166,
#  'fast': 2497,
#  'furious': 2758,
#  'air': 319,
#  'conflicts': 1552,
#  'vietnam': 7171,
#  'd': 1753,
#  'radio': 5319,
#  'control': 1583,
#  'brains': 1035,
#  'elebits': 2252,
#  'escape': 2338,
#  'carmen': 1237,
#  'sandiego': 5728,
#  'secret': 5814,
#  'stolen': 6384,
#  'drums': 2143,
#  'shrek': 5957,
#  'superslam': 6485,
#  'hell': 3185,
#  'yeah': 7508,
#  'interceptor': 3475,
#  'harrier': 3135,
#  'complete': 1538,
#  'hall': 3091,
#  'fame': 2479,
#  'williams': 7355,
#  'nuka': 4677,
#  'eyes': 2441,
#  'alliance': 367,
#  'transformers': 6871,
#  'devastation': 1932,
#  'justice': 3646,
#  'league': 3862,
#  'injustice': 3444,
#  'cyber': 1738,
#  'sled': 6066,
#  'lumines': 4010,
#  'electronic': 2256,
#  'symphony': 6543,
#  'breath': 1060,
#  'fire': 2571,
#  'gyrostarr': 3076,
#  'de': 1832,
#  'blob': 913,
#  'dungeonland': 2169,
#  'tamriel': 6579,
#  'unlimited': 7075,
#  'he': 3158,
#  'powerful': 5139,
#  'universe': 7069,
#  'blazing': 900,
#  'angels': 436,
#  'squadrons': 6281,
#  'wwii': 7450,
#  'men': 4219,
#  'wolverine': 7398,
#  'zombie': 7574,
#  'chav': 1343,
#  'hunt': 3331,
#  'drill': 2120,
#  'sergeant': 5844,
#  'mindstrong': 4291,
#  'tony': 6791,
#  'hawk': 3150,
#  'military': 4276,
#  'madness': 4039,
#  'team': 6610,
#  'kinect': 3733,
#  '8': 193,
#  'battlefront': 744,
#  'renegade': 5459,
#  'squadron': 6280,
#  'modern': 4356,
#  'warfare': 7252,
#  'federation': 2521,
#  'apple': 479,
#  'jack': 3537,
#  'bugs': 1120,
#  'bunny': 1146,
#  'taz': 6604,
#  'busters': 1165,
#  'payne': 4927,
#  'double': 2073,
#  'mvp': 4477,
#  'baseball': 716,
#  'luxor': 4017,
#  'exodus': 2407,
#  'frogger': 2727,
#  'swampy': 6512,
#  'revenge': 5502,
#  'monaco': 4364,
#  'prix': 5188,
#  'ford': 2661,
#  'bold': 964,
#  'moves': 4429,
#  '2k10': 130,
#  'surgeon': 6496,
#  '2013': 92,
#  'mass': 4141,
#  'effect': 2234,
#  'kasumi': 3684,
#  'memory': 4218,
#  'europa': 2364,
#  'universalis': 7068,
#  'breakaway': 1050,
#  'house': 3311,
#  'california': 1193,
#  'gold': 2936,
#  'undertale': 7041,
#  'macintosh': 4032,
#  'primal': 5173,
#  '07': 11,
#  'asphalt': 559,
#  'tv': 6981,
#  ...}

# %%
def convert_X_to_X_word_ids(X):
    return X.apply( lambda x: [vocab[w] for w in [w.lower().strip() for w in x.split()] if w in vocab] )

# %%
X_train_word_ids = convert_X_to_X_word_ids(X_train)
X_test_word_ids  = convert_X_to_X_word_ids(X_test)

# %%
X_train_word_ids.head()
# Out:
# 16138                 [3134, 4717, 1911, 5074, 149, 269]
# 5945     [3730, 5126, 1888, 2799, 1025, 266, 5062, 2227]
# 11360                   [4037, 4585, 13, 5074, 77, 6257]
# 18270                      [7447, 136, 7458, 4751, 7439]
# 12533                      [6674, 3843, 4617, 1533, 251]
# Name: text, dtype: object

# %%
print('X_train_word_ids.shape:', X_train_word_ids.shape)
print('X_test_word_ids.shape:', X_test_word_ids.shape)
# Out:
# X_train_word_ids.shape: (16759,)
# X_test_word_ids.shape: (1863,)

# %%
#Sequence Padding
X_train_padded_seqs = pad_sequences(X_train_word_ids, maxlen=20, value=0)
X_test_padded_seqs = pad_sequences(X_test_word_ids, maxlen=20, value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-5270c74a9d8c> in <module>()
#       1 #Sequence Padding
# ----> 2 X_train_padded_seqs = pad_sequences(X_train_word_ids, maxlen=20, value=0)
#       3 X_test_padded_seqs = pad_sequences(X_test_word_ids, maxlen=20, value=0)
#
# NameError: name 'pad_sequences' is not defined

# %%
pd.DataFrame(X_train_padded_seqs).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-af3ab72d4da8> in <module>()
# ----> 1 pd.DataFrame(X_train_padded_seqs).head()
#
# NameError: name 'X_train_padded_seqs' is not defined

# %%
pd.DataFrame(X_test_padded_seqs).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-54ab1f726178> in <module>()
# ----> 1 pd.DataFrame(X_test_padded_seqs).head()
#
# NameError: name 'X_test_padded_seqs' is not defined

# %%
#Convert (y) labels to vectors
unique_y_labels = list(y_train.value_counts().index)
unique_y_labels
# Out:
# ['Great',
#  'Good',
#  'Okay',
#  'Mediocre',
#  'Amazing',
#  'Bad',
#  'Awful',
#  'Painful',
#  'Unbearable',
#  'Masterpiece']

# %%
len(unique_y_labels)
# Out:
# 10

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(unique_y_labels)
# Out:
# LabelEncoder()

# %%
#One hot array
y_train = to_categorical(y_train.map(lambda x: le.transform([x])[0]), nb_classes=len(unique_y_labels))
y_test  = to_categorical(y_test.map(lambda x:  le.transform([x])[0]), nb_classes=len(unique_y_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-a7beb2926eb8> in <module>()
# ----> 1 y_train = to_categorical(y_train.map(lambda x: le.transform([x])[0]), nb_classes=len(unique_y_labels))
#       2 y_test  = to_categorical(y_test.map(lambda x:  le.transform([x])[0]), nb_classes=len(unique_y_labels))
#
# NameError: name 'to_categorical' is not defined

# %%
y_train[0:3]
# Out:
# 16138     Good
# 5945     Great
# 11360     Good
# Name: score_phrase, dtype: object

# %%
print('y_train.shape:', y_train.shape)
print('y_test.shape:', y_test.shape)
# Out:
# y_train.shape: (16759,)
# y_test.shape: (1863,)

# %%
#RNN Network building
size_of_each_vector = X_train_padded_seqs.shape[1]
vocab_size = len(vocab)
no_of_unique_y_labels = len(unique_y_labels)

# %%
print('size_of_each_vector:', size_of_each_vector)
print('vocab_size:', vocab_size)
print('no_of_unique_y_labels:', no_of_unique_y_labels)
# Out:
# vocab_size: 7596
# no_of_unique_y_labels: 10

# %%
#sgd = tflearn.SGD(learning_rate=1e-4, lr_decay=0.96, decay_step=1000)
net = tflearn.input_data([None, size_of_each_vector]) # The first element is the "batch size" which we set to "None"
net = tflearn.embedding(net, input_dim=vocab_size, output_dim=128) # input_dim: vocabulary size
net = tflearn.lstm(net, 128, dropout=0.6) # Set the dropout to 0.6
net = tflearn.fully_connected(net, no_of_unique_y_labels, activation='softmax') # relu or softmax
net = tflearn.regression(net, 
                         optimizer='adam',  # adam or ada or adagrad # sgd
                         learning_rate=1e-4,
                         loss='categorical_crossentropy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-57e54d973a2f> in <module>()
#       1 #sgd = tflearn.SGD(learning_rate=1e-4, lr_decay=0.96, decay_step=1000)
# ----> 2 net = tflearn.input_data([None, size_of_each_vector]) # The first element is the "batch size" which we set to "None"
#       3 net = tflearn.embedding(net, input_dim=vocab_size, output_dim=128) # input_dim: vocabulary size
#       4 net = tflearn.lstm(net, 128, dropout=0.6) # Set the dropout to 0.6
#       5 net = tflearn.fully_connected(net, no_of_unique_y_labels, activation='softmax') # relu or softmax
#
# NameError: name 'tflearn' is not defined

# %%
#model = tflearn.DNN(net, tensorboard_verbose=0, checkpoint_path='SavedModels/model.tfl.ckpt')
model = tflearn.DNN(net, tensorboard_verbose=0)
#Train model

# model.fit(X_train_padded_seqs, y_train, 
#           validation_set=(X_test_padded_seqs, y_test), 
#           n_epoch=n_epoch,
#           show_metric=True, 
#           batch_size=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-b2bc69c98b50> in <module>()
#       1 #model = tflearn.DNN(net, tensorboard_verbose=0, checkpoint_path='SavedModels/model.tfl.ckpt')
# ----> 2 model = tflearn.DNN(net, tensorboard_verbose=0)
#       3 #Train model
#       4
#       5 # model.fit(X_train_padded_seqs, y_train,
#
# NameError: name 'tflearn' is not defined

# %%
# model.save('SavedModels/model.tfl')

# %%
#load model
model.load('SavedModels/model.tfl')
Print("Model Loaded!!!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-3fca257f6b65> in <module>()
#       1 #load model
# ----> 2 model.load('SavedModels/model.tfl')
#       3 Print("Model Loaded!!!")
#
# NameError: name 'model' is not defined

# %%
#RNN's Accuracy
pred_classes = [np.argmax(i) for i in model.predict(X_test_padded_seqs)]
true_classes = [np.argmax(i) for i in y_test]
print('\nRNN Classifier\'s Accuracy: %0.5f\n' % metrics.accuracy_score(true_classes, pred_classes))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-4beb7046f745> in <module>()
#       1 #RNN's Accuracy
# ----> 2 pred_classes = [np.argmax(i) for i in model.predict(X_test_padded_seqs)]
#       3 true_classes = [np.argmax(i) for i in y_test]
#       4 print('\nRNN Classifier\'s Accuracy: %0.5f\n' % metrics.accuracy_score(true_classes, pred_classes))
#
# NameError: name 'model' is not defined

# %%
#Show some predicted samples
ids_of_titles = range(0,21) # range(X_test.shape[0]) 
for i in ids_of_titles:
    pred_class = np.argmax(model.predict([X_test_padded_seqs[i]]))
    true_class = np.argmax(y_test[i])
    
    print(X_test.values[i])
    print('pred_class:', le.inverse_transform(pred_class))
    print('true_class:', le.inverse_transform(true_class))
    print('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-1dd6c6ff2b0e> in <module>()
#       2 ids_of_titles = range(0,21) # range(X_test.shape[0])
#       3 for i in ids_of_titles:
# ----> 4     pred_class = np.argmax(model.predict([X_test_padded_seqs[i]]))
#       5     true_class = np.argmax(y_test[i])
#       6
#
# NameError: name 'np' is not defined
